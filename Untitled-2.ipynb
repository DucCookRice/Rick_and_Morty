# %%
from image_preprocess import data_set
from keras.utils import to_categorical
import sys
from matplotlib import pyplot
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.optimizers import SGD
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
from keras.preprocessing.image import array_to_img

def load_data_set():
	le = preprocessing.LabelEncoder()
	enc = OneHotEncoder()
	X_train , X_test , Y_train , Y_test = load_data()
	Y_train = enc.fit_transform(le.fit_transform(Y_train))
	Y_test = enc.fit((le.fit_transform(Y_test)))
	return X_train , X_test , Y_train , Y_test

# define cnn model

def CNN_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200, 200, 3)))
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.3))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.4))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dropout(0.5))
	model.add(Dense(5, activation='softmax'))
	# compile model
	opt = SGD(lr=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

def test_img(image , character_name ):
	image = img
	img = img*255
	img =array_to_img(img)

	print("This is "+character_name)
	return img

def run_model(epoch):
	epoch = epoch
	model = CNN_model()

	history = model.fit(X_train, Y_train, epochs=epoch, batch_size=64, validation_data=(X_test, Y_test), verbose=0)

	_, acc = model.evaluate(X_test, Y_test, verbose=0)

	print('> %.3f' % (acc * 100.0))
	
	return model
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-76-89ffcdbb14f6> in <module>
# ----> 1 from image_preprocess import data_set
#       2 from keras.utils import to_categorical
#       3 import sys
#       4 from matplotlib import pyplot
#       5 from keras.models import Sequential
#
# ImportError: cannot import name 'data_set'

# %%
X_train , X_test , Y_train , Y_test = load_data_set()
input_shape = (200,200,3)
run_model(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-8b0d2bd5527e> in <module>
# ----> 1 X_train , X_test , Y_train , Y_test = load_data_set()
#       2 input_shape = (200,200,3)
#       3 run_model(1)
#
# <ipython-input-72-1a465a143f0e> in load_data_set()
#      18         enc = OneHotEncoder()
#      19         X_train , X_test , Y_train , Y_test = load_data()
# ---> 20         Y_train = enc.fit_transform(le.fit_transform(Y_train))
#      21         Y_test = enc.fit((le.fit_transform(Y_test)))
#      22         return X_train , X_test , Y_train , Y_test
#
# ~\anaconda3\envs\AIduc\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     408         """
#     409         self._validate_keywords()
# --> 410         return super().fit_transform(X, y)
#     411
#     412     def transform(self, X):
#
# ...

# %%
# Out:
# ['Poopybutthole' 'Rick' 'Morty' ... 'Morty' 'Meeseeks' 'Rick']

# %%
test_img(X_train[0])
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2C156B32BE0>
